# %%
import crooked_numbers_analytics
from crooked_numbers_analytics.db import open_database
from crooked_numbers_analytics.settings import Settings

# %%
settings = Settings.from_env()
connection = open_database(settings)
print(f"Package: {crooked_numbers_analytics.__name__}")
print(f"Storage account URL: {settings.azure_storage_account_url or 'not configured'}")
print(f"Storage container: {settings.azure_storage_container}")
connection.execute("SELECT 1").fetchone()
